# %%
import tensorflow as tf
import keras
from keras.datasets import boston_housing

(X_train, y_train), (X_test, y_test) = boston_housing.load_data()

# %%
from sklearn.preprocessing import StandardScaler
standard_scaler = StandardScaler()
X_train = standard_scaler.fit_transform(X_train)
X_test = standard_scaler.fit_transform(X_test)
print(X_train.shape)
print(X_train.dtype)
# Out:
# (404, 13)
# float64

# %%
def splitTrainSimply(train_data, valid_rate=0.25):
    data_len = train_data.shape[0]
    border = int(data_len * valid_rate)
    return train_data[border:], train_data[:border]

X_train, X_valid = splitTrainSimply(X_train)
y_train, y_valid = splitTrainSimply(y_train)
print(X_train.shape)
print(X_valid.shape)
print(y_train.shape)
print(y_valid.shape)
# Out:
# (303, 13)
# (101, 13)
# (303,)
# (101,)

# %%
from keras import models
from keras import layers
from keras import activations
simple_model = models.Sequential(
    [
        layers.InputLayer(input_shape=X_train.shape[1:]),
        layers.Dense(30, activation=activations.relu),
        layers.Dense(1)
    ]
)

# %%
from keras import optimizers
from keras import losses
from keras import metrics
simple_model.compile(
    optimizer=optimizers.SGD(), loss=losses.MeanSquaredError(), metrics=[metrics.MeanAbsoluteError()]
)

# %%
history = simple_model.fit(X_train, y_train, epochs=20, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/20
# 10/10 [==============================] - 0s 15ms/step - loss: 232.2238 - mean_absolute_error: 11.8125 - val_loss: 29.4591 - val_mean_absolute_error: 3.6160
# Epoch 2/20
# 10/10 [==============================] - 0s 5ms/step - loss: 26.4400 - mean_absolute_error: 3.6781 - val_loss: 22.6101 - val_mean_absolute_error: 3.1062
# Epoch 3/20
# 10/10 [==============================] - 0s 5ms/step - loss: 20.8783 - mean_absolute_error: 3.3325 - val_loss: 24.5649 - val_mean_absolute_error: 3.8009
# Epoch 4/20
# 10/10 [==============================] - 0s 6ms/step - loss: 18.0922 - mean_absolute_error: 3.0667 - val_loss: 14.1864 - val_mean_absolute_error: 2.4867
# Epoch 5/20
# 10/10 [==============================] - 0s 6ms/step - loss: 14.1457 - mean_absolute_error: 2.6026 - val_loss: 12.9419 - val_mean_absolute_error: 2.3263
# Epoch 6/20
# 10/10 [==============================] - 0s 5ms/step - loss: 14.9368 - mean_absolute_error: 2.7471 - val_loss: 14.4345 - val_mean_absolute_error: 2.5446
# Epoch 7/20
# 10/10 [==============================] - 0s 6ms/step - loss: 12.8427 - mean_absolute_error: 2.5599 - val_loss: 9.6060 - val_mean_absolute_error: 2.2225
# Epoch 8/20
# 10/10 [==============================] - 0s 6ms/step - loss: 13.1164 - mean_absolute_error: 2.5990 - val_loss: 11.0221 - val_mean_absolute_error: 2.5014
# Epoch 9/20
# 10/10 [==============================] - 0s 4ms/step - loss: 12.1655 - mean_absolute_error: 2.4321 - val_loss: 9.1362 - val_mean_absolute_error: 2.2284
# Epoch 10/20
# 10/10 [==============================] - 0s 5ms/step - loss: 12.3399 - mean_absolute_error: 2.5175 - val_loss: 10.5929 - val_mean_absolute_error: 2.1687
# Epoch 11/20
# 10/10 [==============================] - 0s 7ms/step - loss: 12.1952 - mean_absolute_error: 2.5950 - val_loss: 9.1335 - val_mean_absolute_error: 2.0024
# Epoch 12/20
# 10/10 [==============================] - 0s 5ms/step - loss: 10.5993 - mean_absolute_error: 2.2189 - val_loss: 9.1814 - val_mean_absolute_error: 2.1327
# Epoch 13/20
# 10/10 [==============================] - 0s 5ms/step - loss: 10.5923 - mean_absolute_error: 2.3146 - val_loss: 15.5298 - val_mean_absolute_error: 2.9457
# Epoch 14/20
# 10/10 [==============================] - 0s 4ms/step - loss: 12.2505 - mean_absolute_error: 2.5385 - val_loss: 18.2817 - val_mean_absolute_error: 3.3838
# Epoch 15/20
# 10/10 [==============================] - 0s 5ms/step - loss: 11.9226 - mean_absolute_error: 2.4872 - val_loss: 8.2188 - val_mean_absolute_error: 2.0535
# Epoch 16/20
# 10/10 [==============================] - 0s 4ms/step - loss: 9.8607 - mean_absolute_error: 2.2142 - val_loss: 7.5740 - val_mean_absolute_error: 1.9670
# Epoch 17/20
# 10/10 [==============================] - 0s 5ms/step - loss: 11.2442 - mean_absolute_error: 2.3993 - val_loss: 7.7546 - val_mean_absolute_error: 1.9524
# Epoch 18/20
# 10/10 [==============================] - 0s 4ms/step - loss: 9.8747 - mean_absolute_error: 2.2693 - val_loss: 10.3683 - val_mean_absolute_error: 2.3536
# Epoch 19/20
# 10/10 [==============================] - 0s 5ms/step - loss: 10.1890 - mean_absolute_error: 2.2750 - val_loss: 8.6907 - val_mean_absolute_error: 2.0600
# Epoch 20/20
# 10/10 [==============================] - 0s 4ms/step - loss: 10.4642 - mean_absolute_error: 2.2636 - val_loss: 10.3521 - val_mean_absolute_error: 2.1900

# %%
import pandas as pd
import matplotlib.pyplot as plt

pd.DataFrame(history.history).plot()
plt.ylim((0, 50))
plt.grid(True)

# %%
simple_model.evaluate(X_test, y_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 18.7923 - mean_absolute_error: 3.2520
# [18.792285919189453, 3.2519969940185547]
