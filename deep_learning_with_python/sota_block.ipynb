# %%
import tensorflow as tf


def get_res_model() -> tf.keras.Model:
    model_input = tf.keras.Input((256, 256, 3))

    module_input = model_input
    module_input_channel = 3
    for channel in [32, 32]:
        x = tf.keras.layers.Conv2D(channel, 3, padding="same", activation="relu")(module_input)
        x = tf.keras.layers.Conv2D(channel, 3, padding="same", activation="relu")(x)
        module_input = tf.pad(module_input,[[0,0],[0,0], [0,0], [0, channel - module_input_channel]])
        module_output = tf.keras.layers.Add()([x, module_input])

        
        module_input = module_output
        module_input_channel = channel

    x = tf.keras.layers.Flatten()(module_output)
    model_output = tf.keras.layers.Dense(2, activation="sigmoid")(x)

    return tf.keras.Model(inputs=model_input, outputs=model_output, name="Residual Model")

res_model = get_res_model()
res_model.summary()
# Out:
# Model: "Residual Model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_8 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_32 (Conv2D)             (None, 256, 256, 32  896         ['input_8[0][0]']
#                                 )
#
#  conv2d_33 (Conv2D)             (None, 256, 256, 32  9248        ['conv2d_32[0][0]']
#                                 )
#
#  tf.compat.v1.pad_8 (TFOpLambda  (None, 256, 256, 32  0          ['input_8[0][0]']
#  )                              )
#
#  add_16 (Add)                   (None, 256, 256, 32  0           ['conv2d_33[0][0]',
#                                 )                                 'tf.compat.v1.pad_8[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 256, 256, 32  9248        ['add_16[0][0]']
#                                 )
#
#  conv2d_35 (Conv2D)             (None, 256, 256, 32  9248        ['conv2d_34[0][0]']
#                                 )
#
#  tf.compat.v1.pad_9 (TFOpLambda  (None, 256, 256, 32  0          ['add_16[0][0]']
#  )                              )
#
#  add_17 (Add)                   (None, 256, 256, 32  0           ['conv2d_35[0][0]',
#                                 )                                 'tf.compat.v1.pad_9[0][0]']
#
#  flatten_7 (Flatten)            (None, 2097152)      0           ['add_17[0][0]']
#
#  dense_7 (Dense)                (None, 2)            4194306     ['flatten_7[0][0]']
#
# ==================================================================================================
# Total params: 4,222,946
# Trainable params: 4,222,946
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
def get_xception_model():
    model_input = tf.keras.Input((256, 256, 3))

    block_input = model_input
    for channel in [64, 128, 256]:
        x = tf.keras.layers.BatchNormalization()(block_input)
        x = tf.keras.layers.ReLU()(x)
        x = tf.keras.layers.SeparableConv2D(channel, 3, padding="same", use_bias=False)(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.layers.ReLU()(x)
        x = tf.keras.layers.MaxPool2D()(x)
        x = tf.keras.layers.Conv2D(channel, 1, padding="same", use_bias=False)(x)
        
        y = tf.keras.layers.Conv2D(channel, 1, strides=2, padding="same")(block_input)

        block_output = tf.keras.layers.Add()([x, y])

        block_input = block_output
    
    x = tf.keras.layers.Flatten()(block_output)
    model_output = tf.keras.layers.Dense(2, activation="sigmoid")(x)
    return tf.keras.Model(inputs=model_input, outputs=model_output, name="Xception Model")

xception_model = get_xception_model()
xception_model.summary()
# Out:
# Model: "Xception Model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_9 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  batch_normalization_16 (BatchN  (None, 256, 256, 3)  12         ['input_9[0][0]']
#  ormalization)
#
#  re_lu_16 (ReLU)                (None, 256, 256, 3)  0           ['batch_normalization_16[0][0]']
#
#  separable_conv2d_8 (SeparableC  (None, 256, 256, 64  219        ['re_lu_16[0][0]']
#  onv2D)                         )
#
#  batch_normalization_17 (BatchN  (None, 256, 256, 64  256        ['separable_conv2d_8[0][0]']
#  ormalization)                  )
#
#  re_lu_17 (ReLU)                (None, 256, 256, 64  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 128, 128, 64  0          ['re_lu_17[0][0]']
#                                 )
#
#  conv2d_36 (Conv2D)             (None, 128, 128, 64  4096        ['max_pooling2d_8[0][0]']
#                                 )
#
#  conv2d_37 (Conv2D)             (None, 128, 128, 64  256         ['input_9[0][0]']
#                                 )
#
#  add_18 (Add)                   (None, 128, 128, 64  0           ['conv2d_36[0][0]',
#                                 )                                 'conv2d_37[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 128, 128, 64  256        ['add_18[0][0]']
#  ormalization)                  )
#
#  re_lu_18 (ReLU)                (None, 128, 128, 64  0           ['batch_normalization_18[0][0]']
#                                 )
#
#  separable_conv2d_9 (SeparableC  (None, 128, 128, 12  8768       ['re_lu_18[0][0]']
#  onv2D)                         8)
#
#  batch_normalization_19 (BatchN  (None, 128, 128, 12  512        ['separable_conv2d_9[0][0]']
#  ormalization)                  8)
#
#  re_lu_19 (ReLU)                (None, 128, 128, 12  0           ['batch_normalization_19[0][0]']
#                                 8)
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 64, 64, 128)  0          ['re_lu_19[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 64, 64, 128)  16384       ['max_pooling2d_9[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 64, 64, 128)  8320        ['add_18[0][0]']
#
#  add_19 (Add)                   (None, 64, 64, 128)  0           ['conv2d_38[0][0]',
#                                                                   'conv2d_39[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 64, 64, 128)  512        ['add_19[0][0]']
#  ormalization)
#
#  re_lu_20 (ReLU)                (None, 64, 64, 128)  0           ['batch_normalization_20[0][0]']
#
#  separable_conv2d_10 (Separable  (None, 64, 64, 256)  33920      ['re_lu_20[0][0]']
#  Conv2D)
#
#  batch_normalization_21 (BatchN  (None, 64, 64, 256)  1024       ['separable_conv2d_10[0][0]']
#  ormalization)
#
#  re_lu_21 (ReLU)                (None, 64, 64, 256)  0           ['batch_normalization_21[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 32, 32, 256)  0          ['re_lu_21[0][0]']
#  )
#
#  conv2d_40 (Conv2D)             (None, 32, 32, 256)  65536       ['max_pooling2d_10[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 32, 32, 256)  33024       ['add_19[0][0]']
#
#  add_20 (Add)                   (None, 32, 32, 256)  0           ['conv2d_40[0][0]',
#                                                                   'conv2d_41[0][0]']
#
#  flatten_8 (Flatten)            (None, 262144)       0           ['add_20[0][0]']
#
#  dense_8 (Dense)                (None, 2)            524290      ['flatten_8[0][0]']
#
# ==================================================================================================
# Total params: 697,385
# Trainable params: 696,099
# Non-trainable params: 1,286
# __________________________________________________________________________________________________
