# %%
import nibabel
import os

hdr_file = os.path.join(".","dataset","Train","HFH_001.hdr")
img_file = os.path.join(".","dataset","Train","HFH_001.img")

img = nibabel.load(hdr_file)
img.shape
# Out:
# (256, 124, 256, 1)

# %%
import matplotlib.pyplot as plt

plt.imshow(img.get_fdata()[:, 15, :, 0])
